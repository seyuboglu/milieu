# %% [markdown]
# # Network Robustness

# %%
# %load_ext autoreload
# %autoreload 2

import sys, os
import json

import numpy as np
import matplotlib.pyplot as plt 
import torch
import seaborn as sns
import pandas as pd
import networkx as nx
from tqdm import tqdm_notebook as tqdm

from dpp.data.network import PPINetwork
from dpp.data.drug import load_drug_targets
from dpp.util import Params, prepare_sns, load_mapping, build_degree_buckets, compute_pvalue
from dpp.data.associations import load_diseases
from dpp.figures.dpp_boxplot import DPPBoxplot

os.chdir("/Users/sabrieyuboglu/Documents/School/SNAP/projects/disease-protein-prediction")
#os.chdir("/dfs/scratch0/sabri/disease-protein-prediction")
prepare_sns(sns)
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
experiment_dir = "experiments/network_robustness/milieu/_figures/dpp_boxplot"
with open(os.path.join(experiment_dir, "params.json" ),'r') as f:
    params = json.load(f)
boxplot_fig = DPPBoxplot(experiment_dir, params["process_params"])
# Out:
# Loading Disease Associations...
# Recall Curve
# Sabri Eyuboglu  -- SNAP Group
# ======================================

# %%
boxplot_fig._generate()
# Out:
# 0.00
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# RW
